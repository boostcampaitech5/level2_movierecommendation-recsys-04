# %%
import pandas as pd

# %%
result_200 = pd.read_csv('./output/valid_result_iter_200.csv')

# %%
def check_use_valid(x):
    origin_cond = (
        x["Dense_Slim_origin"]
        >= x["Admm_Slim_origin"]
        >= x["EASE_origin"]
        >= x["MultiDAE_origin"]
        >= x["RecVAE_origin"]
        >= x["MultiVAE_origin"]
        >= x["SASRec_origin"]
    )
    upgrade_cond = (
        (x["EASE_upgrade"] >= x["EASE_origin"])
        # & (x["MultiDAE_upgrade"] >= x["MultiDAE_origin"])
        & (x["RecVAE_upgrade"] >= x["RecVAE_origin"])
        & ((x["MultiVAE_upgrade"] >= x["MultiVAE_origin"]))
        & (x["SASRec_upgrade"] >= x["SASRec_origin"])
    )

    if origin_cond & upgrade_cond:
        x["use_valid"] = True

    return x

# %%
result = result_200.apply(lambda x: check_use_valid(x), axis=1)

# %%
result
# Out:
#      seed  EASE_origin  Dense_Slim_origin  Admm_Slim_origin  MultiDAE_origin  \
# 0    2732      9.79114           10.04464           9.99809          9.43622
# 1    9845      9.76052            9.97959           9.95663          9.50478
# 2    3264      9.78922            9.98214           9.94962          9.41167
# 3    4859      9.75032            9.97864           9.96971          9.44452
# 4    9225      9.76594            9.98852           9.95057          9.37277
# ..    ...          ...                ...               ...              ...
# 195  1447      9.77200            9.98693           9.96907          9.42730
# 196  5181      9.75989           10.01244          10.00861          9.46684
# 197  5208      9.80134           10.02647           9.96460          9.37149
# 198  6177      9.79974           10.01307           9.93622          9.41837
# 199  4863      9.74139            9.98087           9.97226          9.46269
#
# ...

# %%
result['use_valid'].value_counts()
# Out:
# True     119
# False     81
# Name: use_valid, dtype: int64

# %%
min(abs(result['MultiDAE_origin'] - result['MultiDAE_upgrade']))
# Out:
# 0.04495999999999967

# %%
result[abs(result['MultiDAE_origin'] - result['MultiDAE_upgrade']) < 0.05]
# Out:
#      seed  EASE_origin  Dense_Slim_origin  Admm_Slim_origin  MultiDAE_origin  \
# 167  2282      9.65147            9.88839           9.88329           9.2551
#
#      RecVAE_origin  MultiVAE_origin  SASRec_origin  EASE_upgrade  \
# 167        9.09343          9.06665        4.89987       9.88839
#
#      MultiDAE_upgrade  RecVAE_upgrade  MultiVAE_upgrade  SASRec_upgrade  \
# 167           9.21014         9.15816           9.20121         5.85714
#
#      use_valid
# 167       True

# %% [markdown]
# 최종 시드는 start_seed : 0, end_seed : 2282 (n_iters 는 200)
